# %% [markdown]
# **Installing Requirements**

# %%
# !pip uninstall -y tensorflow                           
# !pip install tensorflow-gpu==1.13.1            #TensorFlow version 1.13.1
# !python3 -c 'import tensorflow as tf; print(tf.__version__)'          #checking tensorflow version
# !pip install rouge                            #installing rouge-1.0.1
# !pip install tensorflow-addons                #installing tensorflow-addons
# Out:
# Found existing installation: tensorflow 2.8.2+zzzcolab20220527125636
# Uninstalling tensorflow-2.8.2+zzzcolab20220527125636:
#   Successfully uninstalled tensorflow-2.8.2+zzzcolab20220527125636
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 345.0 MB 4.2 kB/s
# ...
#      |████████████████████████████████| 3.2 MB 6.6 MB/s
# ...
#      |████████████████████████████████| 50 kB 8.4 MB/s
# ...
#      |████████████████████████████████| 367 kB 65.7 MB/s
# ...
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.8.0
#     Uninstalling tensorflow-estimator-2.8.0:
#       Successfully uninstalled tensorflow-estimator-2.8.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.8.0
#     Uninstalling tensorboard-2.8.0:
#       Successfully uninstalled tensorboard-2.8.0
# ...

# %% [markdown]
# **Cloning Github Repo**

# %%
# !git clone https://github.com/tech-srl/code2seq
# %cd /content/code2seq
# Out:
# Cloning into 'code2seq'...
# remote: Enumerating objects: 286, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 286 (delta 0), reused 0 (delta 0), pack-reused 281
# Receiving objects: 100% (286/286), 4.37 MiB | 18.80 MiB/s, done.
# Resolving deltas: 100% (107/107), done.
# /content/code2seq

# %% [markdown]
# **Mounting Drive**
#
# [Drive containing models and datasets](https://drive.google.com/drive/folders/1SKIlNDUHJ3F7O3jeJA6VQva3pLRovx4v?usp=sharing)
#
# Add shortcut of this drive to your google drive and proceed.

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Inspect Dataset**

# %%
# !sh preprocess.sh

# %% [markdown]
# **Evaluating Model**

# %%
#Java-large model evaluated on java-small dataset
# !python3 code2seq.py --load '/content/drive/MyDrive/code2seq_group3/models/java-large-model/model_iter52.release' --test '/content/drive/MyDrive/code2seq_group3/data/java-small/java-small.test.c2s'
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
#Java-small model evaluated on java-small dataset
# !python3 code2seq.py --load '/content/drive/MyDrive/code2seq_group3/models/java-small/saved_model_iter13' --test '/content/drive/MyDrive/code2seq_group3/data/java-small/java-small.test.c2s'
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
#Downloading and extracting java-medium dataset
# !pwd
# !mkdir data
# !cd data
# !wget https://s3.amazonaws.com/code2seq/datasets/java-med-preprocessed.tar.gz
# !tar -xvzf java-med-preprocessed.tar.gz
# Out:
# /content/code2seq
# --2022-07-06 22:35:20--  https://s3.amazonaws.com/code2seq/datasets/java-med-preprocessed.tar.gz
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.217.45.6
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.217.45.6|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2391834044 (2.2G) [application/x-tar]
# Saving to: ‘java-med-preprocessed.tar.gz’
#
# java-med-preprocess 100%[===================>]   2.23G  12.9MB/s    in 3m 3s
#
# 2022-07-06 22:38:24 (12.5 MB/s) - ‘java-med-preprocessed.tar.gz’ saved [2391834044/2391834044]
#
# java-med/java-med.dict.c2s
# java-med/java-med.test.c2s
# java-med/java-med.train.c2s
# java-med/java-med.val.c2s

# %%
#Evaludating java-large model on java-medium dataset
# !pwd
# !python3 code2seq.py --load '/content/drive/MyDrive/code2seq_group3/models/java-large-model/model_iter52.release' --test /content/code2seq/java-med/java-med.test.c2s
# Out:
# /content/code2seq
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...
