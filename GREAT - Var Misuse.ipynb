# %%
# !git clone https://github.com/VHellendoorn/ICLR20-Great
# Out:
# Cloning into 'ICLR20-Great'...
# remote: Enumerating objects: 148, done.
# remote: Counting objects: 100% (25/25), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 148 (delta 17), reused 13 (delta 13), pack-reused 123
# Receiving objects: 100% (148/148), 192.18 KiB | 5.65 MiB/s, done.
# Resolving deltas: 100% (69/69), done.

# %%
from google. colab import drive
drive. mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp /content/drive/MyDrive/GREAT-checkpoints/great-checkpoint.zip /content/ICLR20-Great

# %%
# !unzip /content/ICLR20-Great/great-checkpoint.zip
# Out:
# Archive:  /content/ICLR20-Great/great-checkpoint.zip
#    creating: great-checkpoint/
#   inflating: great-checkpoint/checkpoint
#   inflating: great-checkpoint/ckpt-100.data-00000-of-00001
#   inflating: great-checkpoint/ckpt-100.index
#   inflating: great-checkpoint/great-log.txt

# %%
# %cd /content/ICLR20-Great
# Out:
# /content/ICLR20-Great

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !git clone https://github.com/google-research-datasets/great --depth=1
# Out:
# Cloning into 'great'...
# remote: Enumerating objects: 907, done.
# remote: Counting objects: 100% (907/907), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 907 (delta 899), reused 904 (delta 899), pack-reused 0
# Receiving objects: 100% (907/907), 2.66 GiB | 45.05 MiB/s, done.
# Resolving deltas: 100% (899/899), done.
# Checking out files: 100% (902/902), done.

# %%
# !python running/run_model.py /content/ICLR20-Great/great vocab.txt config.yml -m /content/ICLR20-Great/great-checkpoint -l /content/ICLR20-Great/great-checkpoint/great-log.txt -e True
# Out:
# 2022-08-09 15:44:27.856983: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# Training with configuration: {'model': {'configuration': 'great', 'base': {'hidden_dim': 512, 'dropout_rate': 0.1, 'num_edge_types': 24}, 'rnn': {'num_layers': 2}, 'ggnn': {'time_steps': [3, 1, 3, 1], 'residuals': {'1': [0], '3': [0, 1]}, 'add_type_bias': True}, 'transformer': {'ff_dim': 2048, 'num_layers': 6, 'attention_dim': 512, 'num_heads': 8}}, 'data': {'max_batch_size': 12500, 'max_buffer_size': 50, 'max_sequence_length': 512, 'valid_interval': 250000, 'max_valid_samples': 25000, 'max_token_length': 10}, 'training': {'max_steps': 100, 'print_freq': 25, 'learning_rate': 0.0001}}
# Testing pre-trained model on full eval data
# Testing progress: MB: 25, seqs: 3,524, tokens: 274,292, loss: 0.412, 0.914, accs: 91.13%, 88.19%, 87.41%, 80.25%
# ...
