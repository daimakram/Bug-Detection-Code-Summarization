# %%
# !git clone https://github.com/wasiahmad/PLBART
# Out:
# Cloning into 'PLBART'...
# remote: Enumerating objects: 645, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 645 (delta 15), reused 13 (delta 13), pack-reused 624
# Receiving objects: 100% (645/645), 3.00 MiB | 20.50 MiB/s, done.
# Resolving deltas: 100% (337/337), done.

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 27.3 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %%
# !wget -O mini.sh https://repo.anaconda.com/miniconda/Miniconda3-py39_4.12.0-Linux-x86_64.sh
# !chmod +x mini.sh
# !bash ./mini.sh -b -f -p /usr/local
# !conda install -q -y jupyter
# !conda install -q -y google-colab -c conda-forge
# !python -m ipykernel install --name “py39” --user
# !conda install --channel defaults conda python=3.9 --yes
# !conda update --channel defaults --all --yes
# !conda install --channel conda-forge featuretools --yes
# !conda install pytorch torchvision torchaudio cudatoolkit=11.1 -c pytorch -c conda-forge --y
# Out:
# --2022-08-04 16:24:31--  https://repo.anaconda.com/miniconda/Miniconda3-py39_4.12.0-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.131.3, 104.16.130.3, 2606:4700::6810:8203, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.131.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 76607678 (73M) [application/x-sh]
# Saving to: ‘mini.sh’
#
# mini.sh             100%[===================>]  73.06M  78.4MB/s    in 0.9s
#
# 2022-08-04 16:24:32 (78.4 MB/s) - ‘mini.sh’ saved [76607678/76607678]
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - _openmp_mutex==4.5=1_gnu
#     - brotlipy==0.7.0=py39h27cfd23_1003
#     - ca-certificates==2022.3.29=h06a4308_1
#     - certifi==2021.10.8=py39h06a4308_2
#     - cffi==1.15.0=py39hd667e15_1
#     - charset-normalizer==2.0.4=pyhd3eb1b0_0
# ...

# %%
# %cd PLBART
# Out:
# /content/PLBART

# %%
# !bash install_env.sh
# Out:
# done
# failed with repodata from current_repodata.json, will retry with next repodata source.
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/plbart
#
#   added / updated specs:
#     - python=3.6.10
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _openmp_mutex-5.1          |            1_gnu          21 KB
#     certifi-2021.5.30          |   py36h06a4308_0         139 KB
#     ld_impl_linux-64-2.38      |       h1181459_1         654 KB
#     libgcc-ng-11.2.0           |       h1234567_1         5.3 MB
#     libgomp-11.2.0             |       h1234567_1         474 KB
#     libstdcxx-ng-11.2.0        |       h1234567_1         4.7 MB
#     ncurses-6.3                |       h5eee18b_3         781 KB
#     pip-21.2.2                 |   py36h06a4308_0         1.8 MB
#     python-3.6.10              |       h7579374_2        29.7 MB
# ...

# %%
# !conda init
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !pwd
# Out:
# /

# %%
# %mkdir /content/PLBART/scripts/code_to_code/defect_prediction/devign/
# %cd /content/PLBART/scripts/code_to_code/defect_prediction/devign/
# !cp /content/drive/MyDrive/defect_detection/devign/checkpoint_best.pt .
# !cp /content/drive/MyDrive/defect_detection/devign/result.txt .
# !cp /content/drive/MyDrive/defect_detection/devign/finetune.log .
# %cd ..
# Out:
# /content/PLBART/scripts/code_to_code/defect_prediction/devign
# /content/PLBART/scripts/code_to_code/defect_prediction

# %%
# %cd /content/PLBART/data/codeXglue
# !cp /content/drive/MyDrive/code-to-code.zip /content/PLBART/data/codeXglue/
# !unzip code-to-code.zip
# !rm code-to-code.zip
# %cd ../..
# Out:
# /content/PLBART/data/codeXglue
# Archive:  code-to-code.zip
#    creating: code-to-code/
#    creating: code-to-code/translation/
#   inflating: code-to-code/translation/valid.java-cs.txt.java
#   inflating: code-to-code/translation/valid.java-cs.txt.cs
#   inflating: code-to-code/translation/train.java-cs.txt.java
#   inflating: code-to-code/translation/train.java-cs.txt.cs
#   inflating: code-to-code/translation/test.java-cs.txt.cs
#   inflating: code-to-code/translation/test.java-cs.txt.java
#    creating: code-to-code/refinement/
#    creating: code-to-code/refinement/small/
#   inflating: code-to-code/refinement/small/valid.buggy-fixed.buggy
#   inflating: code-to-code/refinement/small/test.buggy-fixed.fixed
#   inflating: code-to-code/refinement/small/valid.buggy-fixed.fixed
#   inflating: code-to-code/refinement/small/train.buggy-fixed.fixed
#   inflating: code-to-code/refinement/small/test.buggy-fixed.buggy
#   inflating: code-to-code/refinement/small/train.buggy-fixed.buggy
# ...

# %%
# %cd evaluation/CodeBLEU/parser
# !bash build.sh
# %cd ../../..
# Out:
# /content/PLBART/evaluation/CodeBLEU/parser
# Cloning into 'tree-sitter-go'...
# remote: Enumerating objects: 1749, done.
# remote: Counting objects: 100% (1748/1748), done.
# remote: Compressing objects: 100% (595/595), done.
# remote: Total 1749 (delta 1131), reused 1705 (delta 1107), pack-reused 1
# Receiving objects: 100% (1749/1749), 8.35 MiB | 16.99 MiB/s, done.
# Resolving deltas: 100% (1131/1131), done.
# Cloning into 'tree-sitter-javascript'...
# remote: Enumerating objects: 3563, done.
# remote: Counting objects: 100% (463/463), done.
# remote: Compressing objects: 100% (186/186), done.
# remote: Total 3563 (delta 276), reused 440 (delta 265), pack-reused 3100
# Receiving objects: 100% (3563/3563), 41.58 MiB | 14.06 MiB/s, done.
# Resolving deltas: 100% (2305/2305), done.
# Cloning into 'tree-sitter-python'...
# remote: Enumerating objects: 2549, done.
# remote: Counting objects: 100% (293/293), done.
# remote: Compressing objects: 100% (131/131), done.
# ...

# %%
# !pip install sklearn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 30.8 MB 110.9 MB/s
# ...
#      |████████████████████████████████| 306 kB 91.8 MB/s
# ...
#      |████████████████████████████████| 43.9 MB 93.1 MB/s
# ...
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1315 sha256=3982e13ec6136bb277af2e408d8a5f8951aab0b212f394a3dc4fd2c1848d2b70
#   Stored in directory: /root/.cache/pip/wheels/e4/7b/98/b6466d71b8d738a0c547008b9eb39bf8676d1ff6ca4b22af1c
# Successfully built sklearn
# ...

# %%
# %cd /content/PLBART/scripts/code_to_code/defect_prediction/
# !bash prepare.sh
# !bash run.sh GPU_IDS
# %cd ../..
#/content/PLBART/data/codeXglue/code-to-code/defect_prediction/processed/data-bin/label/dict.txt
# Out:
# /content/PLBART/scripts/code_to_code/defect_prediction
# Processing: 100% 21854/21854 [00:09<00:00, 2373.27it/s]
# Processing: 100% 2732/2732 [00:01<00:00, 2149.23it/s]
# Processing: 100% 2732/2732 [00:01<00:00, 2128.16it/s]
# ...

# %%
# !python --version
# Out:
# Python 3.9.1

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Thu Aug  4 15:08:22 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...
