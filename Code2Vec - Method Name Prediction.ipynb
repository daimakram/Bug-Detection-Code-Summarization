# %%
# !git clone https://github.com/tech-srl/code2vec
# %cd code2vec
# Out:
# Cloning into 'code2vec'...
# remote: Enumerating objects: 703, done.
# remote: Total 703 (delta 0), reused 0 (delta 0), pack-reused 703
# Receiving objects: 100% (703/703), 5.14 MiB | 7.55 MiB/s, done.
# Resolving deltas: 100% (415/415), done.
# /content/code2vec

# %%
# !wget https://s3.amazonaws.com/code2vec/data/java14m_data.tar.gz
# !tar -xvzf java14m_data.tar.gz
# Out:
# --2022-07-19 14:42:01--  https://s3.amazonaws.com/code2vec/data/java14m_data.tar.gz
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 54.231.128.88
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|54.231.128.88|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6690259728 (6.2G) [application/x-tar]
# Saving to: ‘java14m_data.tar.gz’
#
# java14m_data.tar.gz 100%[===================>]   6.23G  12.8MB/s    in 8m 27s
#
# 2022-07-19 14:50:30 (12.6 MB/s) - ‘java14m_data.tar.gz’ saved [6690259728/6690259728]
#
# data/
# data/java14m/
# data/java14m/java14m.val.c2v
# data/java14m/java14m.test.c2v
# data/java14m/java14m.train.c2v
# data/java14m/java14m.dict.c2v

# %%
# !wget https://s3.amazonaws.com/code2vec/model/java14m_model.tar.gz
# !tar -xvzf java14m_model.tar.gz
# Out:
# --2022-07-19 14:55:33--  https://s3.amazonaws.com/code2vec/model/java14m_model.tar.gz
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.217.192.232
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.217.192.232|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1440921240 (1.3G) [application/x-tar]
# Saving to: ‘java14m_model.tar.gz’
#
# java14m_model.tar.g 100%[===================>]   1.34G  12.9MB/s    in 1m 50s
#
# 2022-07-19 14:57:24 (12.5 MB/s) - ‘java14m_model.tar.gz’ saved [1440921240/1440921240]
#
# models/java14_model/saved_model_iter8.release.data-00000-of-00001
# models/java14_model/saved_model_iter8.release.index
# models/java14_model/saved_model_iter8.release.meta
# models/java14_model/dictionaries.bin

# %%
# !python3 code2vec.py --load models/java14_model/saved_model_iter8.release --test data/java14m/java14m.test.c2v
# Out:
# 2022-07-19 14:58:38.844326: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2022-07-19 14:58:38,854 INFO
# 2022-07-19 14:58:38,854 INFO
# 2022-07-19 14:58:38,854 INFO     ---------------------------------------------------------------------
# 2022-07-19 14:58:38,854 INFO     ---------------------------------------------------------------------
# 2022-07-19 14:58:38,854 INFO     ---------------------- Creating code2vec model ----------------------
# 2022-07-19 14:58:38,854 INFO     ---------------------------------------------------------------------
# 2022-07-19 14:58:38,854 INFO     ---------------------------------------------------------------------
# 2022-07-19 14:58:38,854 INFO     Checking number of examples ...
# 2022-07-19 14:58:42,829 INFO         Number of test examples: 368445
# 2022-07-19 14:58:42,829 INFO     ---------------------------------------------------------------------
# 2022-07-19 14:58:42,829 INFO     ----------------- Configuration - Hyper Parameters ------------------
# 2022-07-19 14:58:42,829 INFO     CODE_VECTOR_SIZE                          384
# 2022-07-19 14:58:42,829 INFO     CSV_BUFFER_SIZE                           104857600
# 2022-07-19 14:58:42,829 INFO     DEFAULT_EMBEDDINGS_SIZE                   128
# 2022-07-19 14:58:42,830 INFO     DL_FRAMEWORK                              tensorflow
# 2022-07-19 14:58:42,830 INFO     DROPOUT_KEEP_RATE                         0.75
# 2022-07-19 14:58:42,830 INFO     EXPORT_CODE_VECTORS                       False
# 2022-07-19 14:58:42,830 INFO     LOGS_PATH                                 None
# 2022-07-19 14:58:42,830 INFO     MAX_CONTEXTS                              200
# 2022-07-19 14:58:42,830 INFO     MAX_PATH_VOCAB_SIZE                       911417
# 2022-07-19 14:58:42,830 INFO     MAX_TARGET_VOCAB_SIZE                     261245
# 2022-07-19 14:58:42,830 INFO     MAX_TOKEN_VOCAB_SIZE                      1301136
# 2022-07-19 14:58:42,830 INFO     MAX_TO_KEEP                               10
# 2022-07-19 14:58:42,830 INFO     MODEL_LOAD_PATH                           models/java14_model/saved_model_iter8.release
# 2022-07-19 14:58:42,830 INFO     MODEL_SAVE_PATH                           None
# 2022-07-19 14:58:42,830 INFO     NUM_BATCHES_TO_LOG_PROGRESS               100
# 2022-07-19 14:58:42,830 INFO     NUM_TEST_EXAMPLES                         368445
# 2022-07-19 14:58:42,830 INFO     NUM_TRAIN_BATCHES_TO_EVALUATE             1800
# 2022-07-19 14:58:42,830 INFO     NUM_TRAIN_EPOCHS                          20
# 2022-07-19 14:58:42,830 INFO     NUM_TRAIN_EXAMPLES                        0
# 2022-07-19 14:58:42,830 INFO     PATH_EMBEDDINGS_SIZE                      128
# 2022-07-19 14:58:42,830 INFO     PREDICT                                   False
# 2022-07-19 14:58:42,830 INFO     READER_NUM_PARALLEL_BATCHES               6
# 2022-07-19 14:58:42,830 INFO     RELEASE                                   False
# 2022-07-19 14:58:42,830 INFO     SAVE_EVERY_EPOCHS                         1
# 2022-07-19 14:58:42,830 INFO     SAVE_T2V                                  None
# 2022-07-19 14:58:42,830 INFO     SAVE_W2V                                  None
# 2022-07-19 14:58:42,831 INFO     SEPARATE_OOV_AND_PAD                      False
# 2022-07-19 14:58:42,831 INFO     SHUFFLE_BUFFER_SIZE                       10000
# 2022-07-19 14:58:42,831 INFO     TARGET_EMBEDDINGS_SIZE                    384
# 2022-07-19 14:58:42,831 INFO     TEST_BATCH_SIZE                           1024
# 2022-07-19 14:58:42,831 INFO     TEST_DATA_PATH                            data/java14m/java14m.test.c2v
# 2022-07-19 14:58:42,831 INFO     TOKEN_EMBEDDINGS_SIZE                     128
# 2022-07-19 14:58:42,831 INFO     TOP_K_WORDS_CONSIDERED_DURING_PREDICTION  10
# 2022-07-19 14:58:42,831 INFO     TRAIN_BATCH_SIZE                          1024
# 2022-07-19 14:58:42,831 INFO     TRAIN_DATA_PATH_PREFIX                    None
# 2022-07-19 14:58:42,831 INFO     USE_TENSORBOARD                           False
# 2022-07-19 14:58:42,831 INFO     VERBOSE_MODE                              1
# 2022-07-19 14:58:42,831 INFO     _Config__logger                           <Logger code2vec (INFO)>
# 2022-07-19 14:58:42,831 INFO     context_vector_size                       384
# 2022-07-19 14:58:42,831 INFO     entire_model_load_path                    models/java14_model/saved_model_iter8.release__entire-model
# 2022-07-19 14:58:42,831 INFO     entire_model_save_path                    None
# 2022-07-19 14:58:42,831 INFO     is_loading                                True
# 2022-07-19 14:58:42,831 INFO     is_saving                                 False
# 2022-07-19 14:58:42,831 INFO     is_testing                                True
# 2022-07-19 14:58:42,831 INFO     is_training                               False
# 2022-07-19 14:58:42,831 INFO     model_load_dir                            models/java14_model
# 2022-07-19 14:58:42,831 INFO     model_weights_load_path                   models/java14_model/saved_model_iter8.release__only-weights
# 2022-07-19 14:58:42,831 INFO     model_weights_save_path                   None
# 2022-07-19 14:58:42,831 INFO     test_steps                                360
# 2022-07-19 14:58:42,831 INFO     train_data_path                           None
# 2022-07-19 14:58:42,831 INFO     train_steps_per_epoch                     0
# 2022-07-19 14:58:42,831 INFO     word_freq_dict_path                       None
# 2022-07-19 14:58:42,832 INFO     ---------------------------------------------------------------------
# 2022-07-19 14:58:42,832 INFO     Loading model vocabularies from: `models/java14_model/dictionaries.bin` ...
# 2022-07-19 14:58:44,845 INFO     Done loading model vocabularies.
# 2022-07-19 14:58:45,511 INFO     Done creating code2vec model
# 2022-07-19 14:59:02,538 INFO     Initalized variables
# 2022-07-19 14:59:02,538 INFO     Loading model weights from: models/java14_model/saved_model_iter8.release
# 2022-07-19 14:59:04,950 INFO     Done loading model weights
# 2022-07-19 14:59:05,261 INFO     Starting evaluation
# 2022-07-19 14:59:48,658 INFO     Evaluated 102400 examples...
# 2022-07-19 14:59:48,658 INFO     Prediction throughput: 2342 samples/sec
# 2022-07-19 15:00:31,188 INFO     Evaluated 204800 examples...
# 2022-07-19 15:00:31,189 INFO     Prediction throughput: 2374 samples/sec
# 2022-07-19 15:01:14,764 INFO     Evaluated 307200 examples...
# 2022-07-19 15:01:14,764 INFO     Prediction throughput: 2366 samples/sec
# 2022-07-19 15:01:40,205 INFO     Done evaluating, epoch reached
# 2022-07-19 15:01:40,205 INFO     Evaluation time: 0H:2M:54S
# 2022-07-19 15:01:40,206 INFO     top10_acc: [0.50086444 0.54063157 0.5556596  0.56424161 0.56990053 0.57424853
#  0.57761945 0.58042313 0.58295811 0.58502626], precision: 0.6582174600509684, recall: 0.5314902438062055, F1: 0.5881043842714981
